# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sbn

# %%
dataFrame = pd.read_excel("merc.xlsx")

# %%
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.count()
# Out:
# year            13119
# price           13119
# transmission    13119
# mileage         13119
# tax             13119
# mpg             13119
# engineSize      13119
# dtype: int64

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
p = plt.figure(figsize=(15,12))
p = sbn.distplot(dataFrame["price"])
# Out:
# C:\Users\doga_\anaconda3\envs\test_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,8))
sbn.countplot(dataFrame["year"])
# Out:
# C:\Users\doga_\anaconda3\envs\test_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
# %matplotlib inline
sbn.scatterplot(x="mileage", y="price", data=dataFrame)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending=False)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# ...     ...     ...          ...      ...  ...   ...         ...
# 11549  2002    1495    Automatic    13800  305  39.8         2.7
# 12594  2004    1495       Manual   119000  300  34.5         1.8
# 11765  2000    1490    Automatic    87000  265  27.2         3.2
# 12008  2010    1350       Manual   116126  145  54.3         2.0
# 11816  2003     650       Manual   109090  235  40.0         1.4
#
# [13119 rows x 7 columns]

# %%
len(dataFrame) * 0.01
# Out:
# 131.19

# %%
noOutlierDf = dataFrame.sort_values("price",ascending=False).iloc[131:]

# %%
noOutlierDf
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11816  2003    650       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
noOutlierDf["price"] *= 19.36

# %%
noOutlierDf
# Out:
#        year       price transmission  mileage  tax   mpg  engineSize
# 6177   2019  1277566.40    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  1277566.40    Semi-Auto      999  145  28.0         4.0
# 3191   2020  1277372.80    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  1258400.00    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  1258380.64    Semi-Auto      119  145  40.9         3.0
# ...     ...         ...          ...      ...  ...   ...         ...
# 11549  2002    28943.20    Automatic    13800  305  39.8         2.7
# 12594  2004    28943.20       Manual   119000  300  34.5         1.8
# 11765  2000    28846.40    Automatic    87000  265  27.2         3.2
# 12008  2010    26136.00       Manual   116126  145  54.3         2.0
# 11816  2003    12584.00       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
sbn.distplot(noOutlierDf["price"])
# Out:
# C:\Users\doga_\anaconda3\envs\test_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
noOutlierDf
# Out:
#        year       price transmission  mileage  tax   mpg  engineSize
# 6177   2019  1277566.40    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  1277566.40    Semi-Auto      999  145  28.0         4.0
# 3191   2020  1277372.80    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  1258400.00    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  1258380.64    Semi-Auto      119  145  40.9         3.0
# ...     ...         ...          ...      ...  ...   ...         ...
# 11549  2002    28943.20    Automatic    13800  305  39.8         2.7
# 12594  2004    28943.20       Manual   119000  300  34.5         1.8
# 11765  2000    28846.40    Automatic    87000  265  27.2         3.2
# 12008  2010    26136.00       Manual   116126  145  54.3         2.0
# 11816  2003    12584.00       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
noOutlierDf["mileage"] *= 1.61

# %%
noOutlierDf
# Out:
#        year       price transmission    mileage  tax   mpg  engineSize
# 6177   2019  1277566.40    Semi-Auto    8172.36  150  30.4         3.0
# 5779   2020  1277566.40    Semi-Auto    1608.39  145  28.0         4.0
# 3191   2020  1277372.80    Semi-Auto    6438.39  145  28.0         4.0
# 4727   2019  1258400.00    Semi-Auto    5470.78  145  27.2         4.0
# 8814   2019  1258380.64    Semi-Auto     191.59  145  40.9         3.0
# ...     ...         ...          ...        ...  ...   ...         ...
# 11549  2002    28943.20    Automatic   22218.00  305  39.8         2.7
# 12594  2004    28943.20       Manual  191590.00  300  34.5         1.8
# 11765  2000    28846.40    Automatic  140070.00  265  27.2         3.2
# 12008  2010    26136.00       Manual  186962.86  145  54.3         2.0
# 11816  2003    12584.00       Manual  175634.90  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
noOutlierDf.rename(columns={"mileage" : "km"})
# Out:
#        year       price transmission         km  tax   mpg  engineSize
# 6177   2019  1277566.40    Semi-Auto    8172.36  150  30.4         3.0
# 5779   2020  1277566.40    Semi-Auto    1608.39  145  28.0         4.0
# 3191   2020  1277372.80    Semi-Auto    6438.39  145  28.0         4.0
# 4727   2019  1258400.00    Semi-Auto    5470.78  145  27.2         4.0
# 8814   2019  1258380.64    Semi-Auto     191.59  145  40.9         3.0
# ...     ...         ...          ...        ...  ...   ...         ...
# 11549  2002    28943.20    Automatic   22218.00  305  39.8         2.7
# 12594  2004    28943.20       Manual  191590.00  300  34.5         1.8
# 11765  2000    28846.40    Automatic  140070.00  265  27.2         3.2
# 12008  2010    26136.00       Manual  186962.86  145  54.3         2.0
# 11816  2003    12584.00       Manual  175634.90  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
dataFrame.groupby("year").count()["price"]
# Out:
# year
# 1970       1
# 1997       1
# 1998       4
# 1999       1
# 2000       3
# 2001      10
# 2002       9
# 2003       7
# 2004      13
# 2005       9
# 2006       8
# 2007      22
# 2008      16
# 2009      17
# 2010      38
# 2011      38
# 2012      57
# 2013     292
# 2014     491
# 2015     991
# 2016    1971
# 2017    2381
# 2018    1467
# 2019    4553
# 2020     719
# Name: price, dtype: int64

# %%
sbn.scatterplot(x="year", y="price", data=noOutlierDf)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
noOutlierDf[noOutlierDf.year != 1970]
# Out:
#        year       price transmission    mileage  tax   mpg  engineSize
# 6177   2019  1277566.40    Semi-Auto    8172.36  150  30.4         3.0
# 5779   2020  1277566.40    Semi-Auto    1608.39  145  28.0         4.0
# 3191   2020  1277372.80    Semi-Auto    6438.39  145  28.0         4.0
# 4727   2019  1258400.00    Semi-Auto    5470.78  145  27.2         4.0
# 8814   2019  1258380.64    Semi-Auto     191.59  145  40.9         3.0
# ...     ...         ...          ...        ...  ...   ...         ...
# 11549  2002    28943.20    Automatic   22218.00  305  39.8         2.7
# 12594  2004    28943.20       Manual  191590.00  300  34.5         1.8
# 11765  2000    28846.40    Automatic  140070.00  265  27.2         3.2
# 12008  2010    26136.00       Manual  186962.86  145  54.3         2.0
# 11816  2003    12584.00       Manual  175634.90  235  40.0         1.4
#
# [12987 rows x 7 columns]

# %%
dataFrame = noOutlierDf[noOutlierDf.year != 1970]

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997    193503.200000
# 1998    166592.800000
# 1999    116063.200000
# 2000    111190.933333
# 2001     95984.944000
# 2002    112683.804444
# 2003     94438.080000
# 2004     91526.633846
# 2005     85689.511111
# 2006     78153.900000
# 2007     99433.840000
# 2008    134889.590000
# 2009    119388.564706
# 2010    160852.050526
# 2011    172564.575135
# 2012    209961.917193
# 2013    231155.350137
# 2014    271871.257678
# 2015    322301.838222
# 2016    372168.101138
# 2017    413457.588952
# 2018    480144.349634
# 2019    586405.200752
# 2020    662785.628718
# Name: price, dtype: float64

# %%
dataFrame
# Out:
#        year       price transmission    mileage  tax   mpg  engineSize
# 6177   2019  1277566.40    Semi-Auto    8172.36  150  30.4         3.0
# 5779   2020  1277566.40    Semi-Auto    1608.39  145  28.0         4.0
# 3191   2020  1277372.80    Semi-Auto    6438.39  145  28.0         4.0
# 4727   2019  1258400.00    Semi-Auto    5470.78  145  27.2         4.0
# 8814   2019  1258380.64    Semi-Auto     191.59  145  40.9         3.0
# ...     ...         ...          ...        ...  ...   ...         ...
# 11549  2002    28943.20    Automatic   22218.00  305  39.8         2.7
# 12594  2004    28943.20       Manual  191590.00  300  34.5         1.8
# 11765  2000    28846.40    Automatic  140070.00  265  27.2         3.2
# 12008  2010    26136.00       Manual  186962.86  145  54.3         2.0
# 11816  2003    12584.00       Manual  175634.90  235  40.0         1.4
#
# [12987 rows x 7 columns]

# %%
dataFrame = dataFrame.drop("transmission",axis=1)

# %%
dataFrame
# Out:
#        year       price    mileage  tax   mpg  engineSize
# 6177   2019  1277566.40    8172.36  150  30.4         3.0
# 5779   2020  1277566.40    1608.39  145  28.0         4.0
# 3191   2020  1277372.80    6438.39  145  28.0         4.0
# 4727   2019  1258400.00    5470.78  145  27.2         4.0
# 8814   2019  1258380.64     191.59  145  40.9         3.0
# ...     ...         ...        ...  ...   ...         ...
# 11549  2002    28943.20   22218.00  305  39.8         2.7
# 12594  2004    28943.20  191590.00  300  34.5         1.8
# 11765  2000    28846.40  140070.00  265  27.2         3.2
# 12008  2010    26136.00  186962.86  145  54.3         2.0
# 11816  2003    12584.00  175634.90  235  40.0         1.4
#
# [12987 rows x 6 columns]

# %%
y = dataFrame["price"].values

# %%
y
# Out:
# array([1277566.4, 1277566.4, 1277372.8, ...,   28846.4,   26136. ,
#          12584. ])

# %%
x = dataFrame.drop("price",axis=1).values

# %%
x
# Out:
# array([[2.0190000e+03, 8.1723600e+03, 1.5000000e+02, 3.0400000e+01,
#         3.0000000e+00],
#        [2.0200000e+03, 1.6083900e+03, 1.4500000e+02, 2.8000000e+01,
#         4.0000000e+00],
#        [2.0200000e+03, 6.4383900e+03, 1.4500000e+02, 2.8000000e+01,
#         4.0000000e+00],
#        ...,
#        [2.0000000e+03, 1.4007000e+05, 2.6500000e+02, 2.7200000e+01,
#         3.2000000e+00],
#        [2.0100000e+03, 1.8696286e+05, 1.4500000e+02, 5.4300000e+01,
#         2.0000000e+00],
#        [2.0030000e+03, 1.7563490e+05, 2.3500000e+02, 4.0000000e+01,
#         1.4000000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train)
# Out:
# 9090

# %%
len(x_test)
# Out:
# 3897

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalar = MinMaxScaler()

# %%
x_train = scalar.fit_transform(x_train)

# %%
x_test = scalar.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9090, 5)

# %%
model = Sequential()
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam", loss="mse")

# %%
model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test),batch_size=250, epochs=300)
# Out:
# Epoch 1/300
# 37/37 [==============================] - 0s 8ms/step - loss: 251928264704.0000 - val_loss: 257912160256.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 1ms/step - loss: 251927674880.0000 - val_loss: 257910898688.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 1ms/step - loss: 251924807680.0000 - val_loss: 257905213440.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 1ms/step - loss: 251913175040.0000 - val_loss: 257883406336.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 2ms/step - loss: 251871592448.0000 - val_loss: 257808580608.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 1ms/step - loss: 251735146496.0000 - val_loss: 257571864576.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 1ms/step - loss: 251333820416.0000 - val_loss: 256914571264.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 1ms/step - loss: 250300448768.0000 - val_loss: 255324880896.0000
# ...

# %%
lossData = pd.DataFrame(model.history.history)

# %%
lossData
# Out:
#              loss      val_loss
# 0    2.519283e+11  2.579122e+11
# 1    2.519277e+11  2.579109e+11
# 2    2.519248e+11  2.579052e+11
# 3    2.519132e+11  2.578834e+11
# 4    2.518716e+11  2.578086e+11
# ..            ...           ...
# 295  7.268390e+09  7.827820e+09
# 296  7.270458e+09  7.806510e+09
# 297  7.264182e+09  7.804554e+09
# 298  7.258849e+09  7.801369e+09
# 299  7.259220e+09  7.805638e+09
#
# [300 rows x 2 columns]

# %%
lossData.plot()
# Out:
# <AxesSubplot:>

# %%
 from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
predictArray = model.predict(x_test)

# %%
predictArray
# Out:
# array([[443299.  ],
#        [444943.  ],
#        [481784.06],
#        ...,
#        [506804.8 ],
#        [228492.66],
#        [475760.5 ]], dtype=float32)

# %%
mean_absolute_error(y_test,predictArray)
# Out:
# 62773.84246964061

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  1.298700e+04   12987.000000  12987.000000  12987.000000
# mean    2017.285516  4.660892e+05   35634.721461    129.676215     55.438392
# std        2.189633  1.910174e+05   34127.930526     65.167429     15.025902
# min     1997.000000  1.258400e+04       1.610000      0.000000      1.100000
# 25%     2016.000000  3.359928e+05   10175.200000    125.000000     45.600000
# 50%     2018.000000  4.317086e+05   24747.310000    145.000000     56.500000
# 75%     2019.000000  5.557482e+05   51498.265000    145.000000     64.200000
# max     2020.000000  1.277566e+06  416990.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.scatter(y_test,predictArray)
plt.plot(y_test,y_test,"y")

# %%
dataFrame.rename(columns={"mileage":"km"},inplace=True)

# %%
dataFrame.iloc[2]
# Out:
# year             2020.00
# price         1277372.80
# km               6438.39
# tax               145.00
# mpg                28.00
# engineSize          4.00
# Name: 3191, dtype: float64

# %%
carFeature = dataFrame.drop("price",axis=1).iloc[2]

# %%
carFeature = scalar.transform(carFeature.values.reshape(-1,5))

# %%
model.predict(carFeature)
# Out:
# array([[1201042.9]], dtype=float32)

# %%
trainLoss = model.evaluate(x_train,y_train, verbose=0)
testLoss = model.evaluate(x_test,y_test,verbose=0)

# %%
trainLoss
# Out:
# 7253491712.0

# %%
testLoss
# Out:
# 7805638144.0

# %%
predicts = model.predict(x_test)

# %%
predictsDf = pd.DataFrame(y_test,columns=["Real Prices"])

# %%
predicts = pd.Series(predicts.reshape(3897,))

# %%
predictsDf = pd.concat([predictsDf,predicts],axis=1)

# %%
predictsDf.columns = ["Real Prices", "Predicted Prices"]

# %%
predictsDf
# Out:
#       Real Prices  Predicted Prices
# 0       406463.20      443299.00000
# 1       383153.76      444943.00000
# 2       538033.76      481784.06250
# 3       842160.00      804063.18750
# 4       271020.64      296866.78125
# ...           ...               ...
# 3892    825684.64      854444.12500
# 3893    335315.20      377401.37500
# 3894    406540.64      506804.81250
# 3895    290400.00      228492.65625
# 3896    518828.64      475760.50000
#
# [3897 rows x 2 columns]
